# %%
#Name:Fardeen Alam
#ID:21301116
#Section:02
#Assignment no:4

# %%
#TASK-1

class Calculator:
    def __init__(self):
        print('Let’s Calculate!')
    def add(self,num_1,num_2):
        self.num_1=num_1
        self.num_2=num_2
        return 'Result: '+str(self.num_1+self.num_2)
    def subtract(self,num_1,num_2):
        self.num_1=num_1
        self.num_2=num_2
        return 'Result: '+str(self.num_1-self.num_2)
    def multiply(self,num_1,num_2):
        self.num_1=num_1
        self.num_2=num_2
        return 'Result: '+str(self.num_1*self.num_2)
    def divide(self,num_1,num_2):
        self.num_1=num_1
        self.num_2=num_2
        return 'Result: '+str(self.num_1/self.num_2)

call=Calculator()
number_1=int(input('Please enter first value:'))
operand=input('Please enter operand:')
number_2=int(input('Please enter second value:'))
if operand=='+':
    print(call.add(number_1,number_2))
elif operand=='-':
    print(call.subtract(number_1,number_2))
elif operand=='*':
    print(call.multiply(number_1,number_2))
else:
    print(call.divide(number_1,number_2))
# Out:
# Let’s Calculate!
# Please enter first value:1
# Please enter operand:+
# Please enter second value:3
# Result: 4

# %%
#TASK-2

class Customer:
    def __init__(self,name):
        self.name=name
    def greet(self,name=None):
        if name!=None:
            print('Hello',name+'!')
        else:
            print('Hello!')
    def purchase(self,*items):
        print(self.name,'you purchased',len(items),'item(s):')
        for content in items:
            print(content)

customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam you purchased 3 item(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David!
# David you purchased 1 item(s):
# orange juice

# %%
#TASK-3

class Panda:
    def __init__(self,name,gender,age):
        self.name=name
        self.gender=gender
        self.age=age
    def sleep(self,hours=-1):
        if hours>=3 and hours<=5:
            return self.name+' sleeps '+str(hours)+' hours daily and should have Mixed Veggies'
        elif hours>=6 and hours<=8:
            return self.name+' sleeps '+str(hours)+' hours daily and should have Eggplant & Tofu'
        elif hours>=9 and hours<=11:
            return self.name+' sleeps'+' '+str(hours)+' '+'hours daily and should have Broccoli Chicken'
        else:
            return self.name+"'s duration is unknown thus should have only bamboo leaves"
panda1 = Panda("Kunfu","Male", 5)
panda2=Panda("Pan Pan","Female",3)
panda3=Panda("Ming Ming","Female",8)

print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))
print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))
print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))
print("===========================")
print(panda2.sleep(10))
print(panda1.sleep(4))
print(panda3.sleep())
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming's duration is unknown thus should have only bamboo leaves

# %%
#TASK-4

class Cat:
    def __init__(self,color='White',action='jumping'):
        self.color=color
        self.action=action

    def changeColor(self,new_color):
        self.color=new_color

    def printCat(self):
        print(self.color,'cat is',self.action)
c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# White cat is jumping
# Black cat is jumping
# Brown cat is jumping
# Red cat is purring
# Blue cat is jumping
# Purple cat is jumping

# %%
#TASK-5

class Student:
    def __init__(self,name='default'):
        self.name=name
    def quizcalc(self,quiz_1=0,quiz_2=0,quiz_3=0):
        self.average=(quiz_1+quiz_2+quiz_3)/3
    def printdetail(self):
        if self.name!='default':
            print('Hello',self.name)
        else:
            print('Hello default student')
        print('Your average quiz score is',self.average)


s1 = Student()
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail()
s2 = Student('Harry')
s2.quizcalc(10,8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10,9,10)
print('--------------------------------')
s3.printdetail()
# Out:
# --------------------------------
# Hello default student
# Your average quiz score is 3.3333333333333335
# --------------------------------
# Hello Harry
# Your average quiz score is 6.0
# --------------------------------
# Hello Hermione
# Your average quiz score is 9.666666666666666

# %%
#TASK-6

class Vehicle:
    def __init__(self,x_coordinate=0,y_coordinate=0):
        self.x_coordinate=x_coordinate
        self.y_coodinate=y_coordinate
    def moveUp(self):
        self.y_coodinate+=1
    def moveDown(self):
        self.y_coodinate+=-1
    def moveLeft(self):
        self.x_coordinate+=-1
    def moveRight(self):
        self.x_coordinate+=1
    def print_position(self):
        print('('+str(self.x_coordinate)+','+str(self.y_coodinate)+')')
car = Vehicle()
car.print_position()
car.moveUp()
car.print_position()
car.moveLeft()
car.print_position()
car.moveDown()
car.print_position()
car.moveRight()
# Out:
# (0,0)
# (0,1)
# (-1,1)
# (-1,0)

# %%
#TASK-7

class Programmer:
    def __init__(self,name,language,experience):
        self.name=name
        self.language=language
        self.experience=experience
    def printDetails(self):
        print('Horray! A new programmer is born')
        print('Name:',self.name)
        print('Language:',self.language)
        print('Experience:',self.experience,'years.')
    def addExp(self,add):
        self.experience+=add
        print('Horray! A new programmer is born')
        print('Name:',self.name)
        print('Language:',self.language)
        print('Experience:',self.experience,'years.')

p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)
p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name: Ethen Hunt
# Language: Java
# Experience: 10 years.
# --------------------------
# Horray! A new programmer is born
# Name: James Bond
# Language: C++
# Experience: 7 years.
# --------------------------
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 4 years.
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 9 years.
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 9 years.

# %%
#TASK-8

class Student:
    def __init__(self,name,id,department='CSE'):
        self.name=name
        self.id=id
        self.department=department
    def dailyEffort(self,effort):
        self.effort=effort
    def printDetails(self):
        print('Name:',self.name)
        print('ID:',self.id)
        print('Department:',self.department)
        print('Daily Effort:',self.effort,'hour(s)')
        if self.effort<=2:
            print('Suggestion: Should give more effort!')
        elif self.effort<=4:
            print('Suggestion: Keep up the good work!')
        else:
            print('Suggestion: Excellent! Now motivate others.')
harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# ID: 123
# Department: CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ...
# Name: John Wick
# ID: 456
# Department: BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ...
# Name: Naruto Uzumaki
# ID: 777
# Department: Ninja
# Daily Effort: 6 hour(s)
# Suggestion: Excellent! Now motivate others.

# %%
#TASK-9

class Patient:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def add_Symptom(self,*symptoms):
        self.symptoms=symptoms
    def printPatientDetail(self):
        print('Name:',self.name)
        print('Age',self.age)
        print('Symptoms:',end='')
        new_string=''
        for content in self.symptoms:
            new_string=new_string+content+','
        print(new_string[:-1])

p1 = Patient('Thomas', 23)
p1.add_Symptom('Headache')
p2 = Patient('Carol', 20)
p2.add_Symptom('Vomiting','Coughing')
p3 = Patient('Mike', 25)
p3.add_Symptom('Fever','Headache','Coughing')
print("=========================")
p1.printPatientDetail()
print("=========================")
p2.printPatientDetail()
print("=========================")
p3.printPatientDetail()
print("=========================")
# Out:
# ...
# Name: Thomas
# Age 23
# Symptoms:Headache
# ...
# Name: Carol
# Age 20
# Symptoms:Vomiting,Coughing
# ...
# Name: Mike
# Age 25
# Symptoms:Fever,Headache,Coughing
# ...

# %%
#TASK-10

class Avengers:
    def __init__(self,name,partner):
        self.name=name
        self.partner=partner
    def super_powers(self,*powers):
        self.powers=powers
    def printAvengersDetail(self):
        print('Name:',self.name)
        print('Partner:',self.partner)
        print('Powers:',end='')
        new_string=''
        for content in self.powers:
            new_string=new_string+content+','
        print(new_string[:-1])

a1 = Avengers('Captain America','Bucky Barnes')
a1.super_powers('Stamina', 'Slowed ageing')
a2 = Avengers('Doctor Strange', 'Ancient One')
a2.super_powers('Mastery of magic')
a3 = Avengers('Iron Man', 'War Machine')
a3.super_powers('Genius level intellect', 'Scientist ')
print("=========================")
a1.printAvengersDetail()
print("=========================")
a2.printAvengersDetail()
print("=========================")
a3.printAvengersDetail()
print("=========================")
# Out:
# ...
# Name: Captain America
# Partner: Bucky Barnes
# Powers:Stamina,Slowed ageing
# ...
# Name: Doctor Strange
# Partner: Ancient One
# Powers:Mastery of magic
# ...
# Name: Iron Man
# Partner: War Machine
# Powers:Genius level intellect,Scientist
# ...

# %%
#TASK-11

class Shinobi:
    def __init__(self,name,rank,mission_num=0,salary=0):
        self.name=name
        self.rank=rank
        self.mission_num=mission_num
        self.salary=salary
    def calSalary(self,mission_num=0,salary=0):
        self.mission_num=mission_num
        self.salary=salary
    def changeRank(self,rank):
        self.rank=rank
    def printInfo(self):
        print('Name:',self.name)
        print('Rank:',self.rank)
        print('Number of mission:',self.mission_num)
        if self.rank == 'Genin':
            self.salary = self.mission_num * 50
        elif self.rank == 'Chunin':
            self.salary = self.mission_num * 100
        else:
            self.salary = self.mission_num * 500
        print('Salary',self.salary)
naruto = Shinobi("Naruto", "Genin")
naruto.calSalary(5)
naruto.printInfo()
print('====================')
shikamaru = Shinobi('Shikamaru', "Genin")
shikamaru.printInfo()
shikamaru.changeRank("Chunin")
shikamaru.calSalary(10)
shikamaru.printInfo()
print('====================')
neiji = Shinobi("Neiji", "Jonin")
neiji.calSalary(5)
neiji.printInfo()
# Out:
# Name: Naruto
# Rank: Genin
# Number of mission: 5
# Salary 250
# ...
# Name: Shikamaru
# Rank: Genin
# Number of mission: 0
# Salary 0
# Name: Shikamaru
# Rank: Chunin
# Number of mission: 10
# Salary 1000
# ...
# Name: Neiji
# Rank: Jonin
# Number of mission: 5
# Salary 2500

# %%
#TASK-12

class ParcelKoro:
    def __init__(self,name=None,product_weight=0,total_fee=0):
        self.name=name
        self.product_weight=product_weight
        self.total_fee=total_fee
    def calculateFee(self,location=None,location_fee=0):
        self.location=location
        self.location_fee=location_fee
        if self.location==None:
            self.location_fee=50
        else:
            self.location_fee=100
        self.total_fee=(self.product_weight*20)+self.location_fee

    def printDetails(self):
        if self.name!=None:
            print('Customer Name:',self.name)
        else:
            print('Customer Name: No name set')
        if self.product_weight==0:
            print('Product Weight: 0')
            print('Total fee: 0')
        else:
            print('Product Weight:',self.product_weight)
            print('Total fee:',self.total_fee)

print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.product_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro('Dora The Explorer', 10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# Out:
# **********************
# Customer Name: No name set
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# ----------------------------
# Customer Name: Bob The Builder
# Product Weight: 15
# Total fee: 350
# **********************
# Customer Name: Dora The Explorer
# Product Weight: 10
# Total fee: 300

# %%
#TASK-13

class Batsman:
    def __init__(self,*values):
        if len(values)==2:
            self.name='New Batsman'
            self.runs=values[0]
            self.balls=values[1]
        elif len(values)==3:
            self.name=values[0]
            self.runs=values[1]
            self.balls=values[2]
    def printCareerStatistics(self):
        print('Name:',self.name)
        print('Runs Scored:',self.runs,',','Balls faced:',self.balls)
    def battingStrikeRate(self,strike_rate=0):
        self.strike_rate=strike_rate
        self.strike_rate=(self.runs/self.balls)*100
        return self.strike_rate
    def setName(self,name):
        self.name=name
b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scored: 6101 , Balls faced: 7380
# ...
# Name: Liton Das
# Runs Scored: 678 , Balls faced: 773
# ----------------------------
# 87.71021992238033
# ...
# Name: Shakib Al Hasan
# Runs Scored: 6101 , Balls faced: 7380
# ----------------------------
# 82.66937669376694

# %%
#TASK-14

class EPL_Team:
    def __init__(self,name,song='No Slogan',title=0):
        self.name=name
        self.song=song
        self.title=title
    def showClubInfo(self):
        print('Name',self.name)
        print('Song:',self.song)
        return 'Total No of title: '+str(self.title)
    def increaseTitle(self):
        self.title+=1
    def changeSong(self,song):
        self.song=song
manu = EPL_Team('Manchester United', 'Glory Glory Man United')
chelsea = EPL_Team('Chelsea')
print('===================')
print(manu.showClubInfo())
print('##################')
manu.increaseTitle()
print(manu.showClubInfo())
print('===================')
print(chelsea.showClubInfo())
chelsea.changeSong('Keep the blue flag flying high')
print(chelsea.showClubInfo())
# Out:
# ...
# Name Manchester United
# Song: Glory Glory Man United
# Total No of title: 0
# ##################
# Name Manchester United
# Song: Glory Glory Man United
# Total No of title: 1
# ...
# Name Chelsea
# Song: No Slogan
# Total No of title: 0
# Name Chelsea
# Song: Keep the blue flag flying high
# Total No of title: 0

# %%
#TASK-15

class Account:
    def __init__(self,name='Default Account',balance=0.0):
        self.name=name
        self.balance=balance
    def details(self):
        print(self.name)
        return self.balance
    def withdraw(self,removal):
        self.removal=removal
        self.new_balance=self.balance-self.removal
        if self.new_balance<3071:
            print('Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.')
        else:
            print('Withdraw successful! New balance is:',self.new_balance)
a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930);
print("------------------------")
a2.withdraw(600);
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is: 3071.0

# %%
#TASK-16

class Author:
    def __init__(self,name='Default',*books):
        self.name=name
        self.books=books
    def addBooks(self,*books):
        self.books=books
    def printDetails(self):
        print('Author Name:',self.name)
        print('--------')
        print('List of Books:')
        for book in self.books:
            print(book)
    def changeName(self,name):
        self.name=name

auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print('===================')
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print('===================')
auth2.printDetails()
print('===================')
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name: Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
# ...
# Default
# ...
# Author Name: Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ...
# Author Name: Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#TASK-17

class Student:
    def __init__(self,name='Default',department='Default'):
        self.name=name
        self.department=department
        if self.name=='Default' and self.department=='Default':
            print('Student name and department need to be set')
        elif self.department=='Default' and self.name!='Default':
            print('Department for',self.name,'needs to be set')
        else:
            print(self.name,'is from',self.department,'department')
    def update_name(self,name):
        self.name=name
    def update_department(self,department):
        self.department=department
    def enroll(self,*courses):
        self.courses=courses
    def printDetail(self):
        new_string=''
        print('Name:',self.name)
        print('Department:',self.department)
        print(self.name,'enrolled in',len(self.courses),'course(s)')
        for subject in self.courses:
            new_string=new_string+subject+','+' '
        print(new_string[:-2])
s1 = Student()
print('=========================')
s2 = Student("Carol")
print("=========================")
s3 = Student("Jon", "EEE")
print("=========================")
s1.update_name("Bob")
s1.update_department("CSE")
s2.update_department("BBA")
s1.enroll("CSE110","MAT110","ENG091")
s2.enroll("BUS101")
s3.enroll("MAT110","PHY111")
print("###########################")
s1.printDetail()
print("=========================")
s2.printDetail()
print("=========================")
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Department for Carol needs to be set
# ...
# Jon is from EEE department
# ...
# ###########################
# Name: Bob
# Department: CSE
# Bob enrolled in 3 course(s)
# CSE110, MAT110, ENG091
# ...
# Name: Carol
# Department: BBA
# Carol enrolled in 1 course(s)
# BUS101
# ...
# Name: Jon
# Department: EEE
# Jon enrolled in 2 course(s)
# MAT110, PHY111

# %%
#TASK-18

class Student:
    def __init__(self,name,id,department):
        self.name=name
        self.id=id
        self.department=department
    def details(self):
        print('Name:', self.name)
        print('ID:', self.id)
        print('Department:', self.department)
    def advise(self,*courses):
        self.courses=courses
        self.credit=len(self.courses)*3.0
        course_string=''
        new_string=''
        for course in self.courses:
            course_string=course_string+course+', '
        if self.credit>=9.0 and self.credit<=12.0:
            new_string='Ok'
        elif self.credit==6.0:
            new_string='You have to take at least 1 more course.'
        elif self.credit==15.0:
            new_string='You have to drop at least 1 course.'
        print(self.name,'you have taken',self.credit,'credits')
        print('List of courses',course_string[:-2])
        print('Status:',new_string)

s1 = Student("Alice","20103012","CSE")
s2 = Student("Bob", "18301254","EEE")
s3 = Student("Carol", "17101238","CSE")
print("##########################")
print(s1.details())
print("##########################")
print(s2.details())
print("##########################")
s1.advise("CSE110","MAT110","PHY111")
print("##########################")
s2.advise("BUS101","MAT120")
print("##########################")
s3.advise("MAT110","PHY111","ENG102","CSE111", "CSE230")
# Out:
# ##########################
# Name: Alice
# ID: 20103012
# Department: CSE
# None
# ##########################
# Name: Bob
# ID: 18301254
# Department: EEE
# None
# ##########################
# Alice you have taken 9.0 credits
# List of courses CSE110, MAT110, PHY111
# Status: Ok
# ##########################
# Bob you have taken 6.0 credits
# List of courses BUS101, MAT120
# Status: You have to take at least 1 more course.
# ##########################
# Carol you have taken 15.0 credits
# List of courses MAT110, PHY111, ENG102, CSE111, CSE230
# Status: You have to drop at least 1 course.

# %%
#TASK-19

class Hotel:
    def __init__(self,hotel_name):
        self.hotel_name=hotel_name
        self.staff_id=0
        self.guest_id=0
        self.staff_list=[]
        self.guest_list=[]
    def addStuff(self,staff_name,staff_age,staff_num='000'):
        self.staff_name=staff_name
        self.staff_age=staff_age
        self.staff_num=staff_num
        self.staff_id+=1
        self.staff_list.append(staff_name)
        self.staff_list.append(staff_age)
        self.staff_list.append(staff_num)
        self.staff_list.append(self.staff_id)
        print('Staff with ID:',self.staff_id,'is created')
    def getStuffById(self,staff_id):
        print('Staff ID:',staff_id)
        print('Name:',self.staff_name)
        print('Age:',self.staff_age)
        return 'Phone no.:'+self.staff_num
    def addGuest(self,guest_name,guest_age,guest_num):
        self.guest_name=guest_name
        self.guest_age=guest_age
        self.guest_num=guest_num
        self.guest_id+=1
        self.guest_list.append(guest_name)
        self.guest_list.append(guest_age)
        self.guest_list.append(guest_num)
        self.guest_list.append(self.guest_id)
        print('Guest with ID',self.guest_id,'is created')
    def getGuestById(self,guest_id):
        print('Guest ID:',guest_id)
        print('Name:',self.guest_name)
        print('Age:',self.guest_age)
        return 'Phone no.:'+self.guest_num
    def allStaffs(self):
        print('All Staffs')
        print('Number of Staff:',int(len(self.staff_list)/4))
        for i in range(0,len(self.staff_list),4):
            print('Staff ID:',self.staff_list[i+3],'Name:',self.staff_list[i],'Age:',self.staff_list[i+1],'Phone no.:',self.staff_list[i+2])
    def allGuest(self):
        print('All Guest:')
        print('Number of Guest:',int(len(self.guest_list)/4))
        for i in range(0,len(self.guest_list),4):
            print('Guest ID:',self.guest_list[i+3],'Name:',self.guest_list[i],'Age:',self.guest_list[i+1],'Phone no.:',self.guest_list[i+2])

h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest("Carol",35,"123")
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, "431")
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# Staff with ID: 1 is created
# ...
# Staff ID: 1
# Name: Adam
# Age: 26
# Phone no.:000
# ...
# Guest with ID 1 is created
# ...
# Guest ID: 1
# Name: Carol
# Age: 35
# Phone no.:123
# ...
# Guest with ID 2 is created
# ...
# Guest ID: 2
# Name: Diana
# Age: 32
# Phone no.:431
# ...
# All Staffs
# Number of Staff: 1
# Staff ID: 1 Name: Adam Age: 26 Phone no.: 000
# ...
# All Guest:
# Number of Guest: 2
# Guest ID: 1 Name: Carol Age: 35 Phone no.: 123
# Guest ID: 2 Name: Diana Age: 32 Phone no.: 431

# %%
#TASK-20

class Author:
    def __init__(self,name=None):
        self.name=name
        self.book_list = {}
        self.count = 0
    def addBook(self,book_name,genre):
        if self.name!=None:
            if genre not in self.book_list:
                self.book_list[genre]=[book_name]
            else:
                self.book_list[genre].append(book_name)
            self.count+=1
        else:
            print('A book can not be added without author name')
    def setName(self,name):
        self.name=name
    def printDetail(self):
        print('Number of Book(s):',self.count)
        print('Author Name:',self.name)
        for key in self.book_list:
            print(key+':',end=' ')
            books=''
            for values in self.book_list[key]:
                books=books+values+','
            print(books[:-1])
a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()
a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# A book can not be added without author name
# ...
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# ...
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# ...
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon,Ireena
# Horror: Megher Upor Bari
# ...

# %%
#TASK-21


class Hospital:
    def __init__(self,hospital_name):
        self.hospital_name=hospital_name
        self.doc_dict={}
        self.pat_dict={}
    def addDoctor(self,doctor):
        self.doc_dict[doctor.id]=[doctor.name,doctor.specialty]
    def getDoctorByID(self,id):
        print("Doctor's ID:",id)
        print('Name:',self.doc_dict[id][0])
        return 'Specialty: '+self.doc_dict[id][1]
    def addPatient(self,patient):
        self.pat_dict[patient.p_id]=[patient.p_name,patient.p_age,patient.p_number]
    def getPatientByID(self,p_id):
        print("Patient's ID:",p_id)
        print('Name:',self.pat_dict[p_id][0])
        print('Age:',self.pat_dict[p_id][1])
        return 'Phone no.: '+str(self.pat_dict[p_id][2])
    def allDoctors(self):
        print('All Doctors:')
        print('Number of Doctors:',len(self.doc_dict))
        print(self.doc_dict)
    def allPatients(self):
        print("All Patients:")
        print('Number of Patients:',len(self.pat_dict))
        print(self.pat_dict)
class Doctor:
    def __init__(self,id,occupation,name,specialty):
        self.id=id
        self.occupation=occupation
        self.name=name
        self.specialty=specialty
class Patient:
    def __init__(self,p_id,p_occupation,p_name,p_age,p_number):
        self.p_id=p_id
        self.p_occupation=p_occupation
        self.p_name=p_name
        self.p_age=p_age
        self.p_number=p_number
h = Hospital("Evercare")
d1 = Doctor("1d","Doctor", "Samar Kumar", "Neurologist")
h.addDoctor(d1)
print("=================================")
print(h.getDoctorByID("1d"))
print("=================================")
p1 = Patient("1p","Patient", "Kashem Ahmed", 35, 12345)
h.addPatient(p1)
print("=================================")
print(h.getPatientByID("1p"))
print("=================================")
p2 = Patient ("2p","Patient", "Tanina Haque", 26, 33456)
h.addPatient(p2)
print("=================================")
print(h.getPatientByID("2p"))
print("=================================")
h.allDoctors()
h.allPatients()
# Out:
# ...
# Doctor's ID: 1d
# Name: Samar Kumar
# Specialty: Neurologist
# ...
# Patient's ID: 1p
# Name: Kashem Ahmed
# Age: 35
# Phone no.: 12345
# ...
# Patient's ID: 2p
# Name: Tanina Haque
# Age: 26
# Phone no.: 33456
# ...
# All Doctors:
# Number of Doctors: 1
# {'1d': ['Samar Kumar', 'Neurologist']}
# All Patients:
# Number of Patients: 2
# {'1p': ['Kashem Ahmed', 35, 12345], '2p': ['Tanina Haque', 26, 33456]}

# %%
#TASK-22

class Vaccine:
    def __init__(self,name,country,day):
        self.name=name
        self.country=country
        self.day=day
class Person:
    def __init__(self,person_name,age,occupation='General Citizen'):
        self.person_name=person_name
        self.age=age
        self.occupation=occupation
        self.vac=''
    def pushVaccine(self,vaccine_name,dose='1st dose'):
        self.first_dose=False
        self.second_dose=False
        if dose=='1st dose':
            if self.age>=25 or self.occupation=='Student':
                self.vac=vaccine_name
                print('1st dose done for',self.person_name)
                self.first_dose=True
            else:
                print('Sorry',self.person_name+',','Minimum age for taking vaccines is 25 years now.')
        else:
            if self.vac.name!=vaccine_name.name:
                print('Sorry',self.person_name+',','you can’t take 2 different vaccines')
            else:
                print('2nd dose done for',self.person_name)
                self.second_dose=True
    def showDetail(self):
        print('Name:',self.person_name,'Age:',self.age,'Type:',self.occupation)
        print('Vaccine name:',self.vac.name)
        if self.second_dose==True:
            print('1st dose: Given')
            print('2nd dose: Given')
        else:
            print('1st dose: Given')
            print('2nd dose: Please come after',str(self.vac.day),'days')

astra = Vaccine("AstraZeneca", "UK", 60)
modr = Vaccine("Moderna", "UK", 30)
sin = Vaccine("Sinopharm", "China", 30)
p1 = Person("Bob", 21, "Student")
print("=================================")
p1.pushVaccine(astra)
print("=================================")
p1.showDetail()
print("=================================")
p1.pushVaccine(sin, "2nd Dose")
print("=================================")
p1.pushVaccine(astra, "2nd Dose")
print("=================================")
p1.showDetail()
print("=================================")
p2 = Person("Carol", 23, "Actor")
print("=================================")
p2.pushVaccine(sin)
print("=================================")
p3 = Person("David", 34)
print("=================================")
p3.pushVaccine(modr)
print("=================================")
p3.showDetail()
print("=================================")
p3.pushVaccine(modr, "2nd Dose")
# Out:
# ...
# 1st dose done for Bob
# ...
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd dose: Please come after 60 days
# ...
# Sorry Bob, you can’t take 2 different vaccines
# ...
# 2nd dose done for Bob
# ...
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd dose: Given
# ...
# Sorry Carol, Minimum age for taking vaccines is 25 years now.
# ...
# 1st dose done for David
# ...
# Name: David Age: 34 Type: General Citizen
# Vaccine name: Moderna
# 1st dose: Given
# 2nd dose: Please come after 30 days
# ...
# 2nd dose done for David
